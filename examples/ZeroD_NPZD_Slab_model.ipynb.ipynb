# %% [markdown]
# # FINAL NPZD PROTOTYPE

# %%
from IPython.display import Image
Image(filename=('NPZDslab_schematics.png'), width=500)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import os,sys,inspect
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import phydra

# %%
from phydra.components.variables import SV

from phydra.components.fluxes.basic import LinearDecay, LinearExchange, QuadraticDecay, QuadraticExchange
from phydra.components.fluxes.growth_multi_lim import Growth_ML, Eppley_ML, Monod_ML, Steele_ML
from phydra.components.fluxes.grazing import (HollingTypeIII_ResourcesListInput_Consumption2Group,
                                              GrossGrowthEfficiency)
from phydra.components.fluxes.ocean_physics import Mixing_K, SlabUpwelling_KfromGroup, SlabMixing_KfromGroup, SlabSinking

from phydra.components.forcings import GlobalSlabClimatologyForcing

# %%
NPZD = phydra.create({
    # State variables
    'Nutrient':SV,
    'Phytoplankton':SV,
    'Zooplankton':SV,
    'Detritus':SV,
    
    # Mixing:
    'K':Mixing_K,
    'Upwelling':SlabUpwelling_KfromGroup,
    'Mixing':SlabMixing_KfromGroup,
    'Sinking':SlabSinking,

    # Growth
    'Growth':Growth_ML,
    'Monod':Monod_ML,
    'Steele':Steele_ML,
    'Eppley':Eppley_ML,
    
    # Grazing
    'Grazing':HollingTypeIII_ResourcesListInput_Consumption2Group,
    'GGE':GrossGrowthEfficiency,
    
    # Mortality 
    'PhytoLinMortality':LinearExchange,
    'PhytoQuadMortality':QuadraticExchange,
    'ZooLinMortality':LinearExchange,
    'HigherOrderPred':QuadraticDecay,
    'DetRemineralisation':LinearExchange,

    # Forcings
    'N0':GlobalSlabClimatologyForcing,
    'Tmld':GlobalSlabClimatologyForcing,
    'I0':GlobalSlabClimatologyForcing,
    'MLD':GlobalSlabClimatologyForcing,
    'MLDderiv':GlobalSlabClimatologyForcing,
                     })

# %%
NPZD.visualize()

# %%
print(NPZD)
# Out:
# <xsimlab.Model (27 processes, 96 inputs)>
# Core
#     solver_type              [in]
# Time
#     time                     [in] ('input_time',) sequence of time ...
# Nutrient
#     var_init                 [in] initial value / basic state variable
#     var_label                [in] label / basic state variable
# Phytoplankton
#     var_label                [in] label / basic state variable
#     var_init                 [in] initial value / basic state variable
# Zooplankton
#     var_init                 [in] initial value / basic state variable
#     var_label                [in] label / basic state variable
# Detritus
#     var_init                 [in] initial value / basic state variable
#     var_label                [in] label / basic state variable
# MLD
#     k                        [in] The degree of the spline fit
#     lat                      [in] constant value of forcing
#     rbb                      [in] constant value of forcing
#     smooth                   [in] smoothing conditions, larger valu...
#     lon                      [in] constant value of forcing
#     forcing_label            [in] label /
#     deriv                    [in] order of derivative to store, for...
#     dataset                  [in] Options: 'n0x', 'mld', 'tmld', 'par'
# Tmld
#     deriv                    [in] order of derivative to store, for...
#     dataset                  [in] Options: 'n0x', 'mld', 'tmld', 'par'
#     smooth                   [in] smoothing conditions, larger valu...
#     k                        [in] The degree of the spline fit
#     lat                      [in] constant value of forcing
#     rbb                      [in] constant value of forcing
#     lon                      [in] constant value of forcing
#     forcing_label            [in] label /
# N0
#     k                        [in] The degree of the spline fit
#     lat                      [in] constant value of forcing
#     rbb                      [in] constant value of forcing
#     smooth                   [in] smoothing conditions, larger valu...
#     lon                      [in] constant value of forcing
#     forcing_label            [in] label /
#     deriv                    [in] order of derivative to store, for...
#     dataset                  [in] Options: 'n0x', 'mld', 'tmld', 'par'
# MLDderiv
#     forcing_label            [in] label /
#     deriv                    [in] order of derivative to store, for...
#     dataset                  [in] Options: 'n0x', 'mld', 'tmld', 'par'
#     rbb                      [in] constant value of forcing
#     smooth                   [in] smoothing conditions, larger valu...
#     k                        [in] The degree of the spline fit
#     lat                      [in] constant value of forcing
#     lon                      [in] constant value of forcing
# I0
#     deriv                    [in] order of derivative to store, for...
#     dataset                  [in] Options: 'n0x', 'mld', 'tmld', 'par'
#     k                        [in] The degree of the spline fit
#     lat                      [in] constant value of forcing
#     rbb                      [in] constant value of forcing
#     smooth                   [in] smoothing conditions, larger valu...
#     lon                      [in] constant value of forcing
#     forcing_label            [in] label /
# K
#     kappa                    [in] constant mixing coefficient
#     mld_deriv                [in] label reference /
#     mld                      [in] label reference /
# Sinking
#     var                      [in] label reference /
#     rate                     [in] sinking rate, units: m d^-1
#     mld                      [in] label reference /
# PhytoQuadMortality
#     source                   [in] label reference /
#     sink                     [in] label reference /
#     rate                     [in] quadratic rate of change
# DetRemineralisation
#     rate                     [in] decay/mortality rate
#     source                   [in] label reference /
#     sink                     [in] label reference /
# HigherOrderPred
#     var                      [in] label reference / variable affect...
#     rate                     [in] quadratic rate of change
# Grazing
#     resources                [in] ('resources',) label reference /
#     kZ                       [in] feeding preferences
#     consumer                 [in] label reference /
#     feed_prefs               [in] ('resources',) feeding preference...
#     Imax                     [in] maximum ingestion rate
# ZooLinMortality
#     sink                     [in] label reference /
#     rate                     [in] decay/mortality rate
#     source                   [in] label reference /
# PhytoLinMortality
#     rate                     [in] decay/mortality rate
#     source                   [in] label reference /
#     sink                     [in] label reference /
# Eppley
#     eppley_exp               [in] eppley exponent
#     temp                     [in] label reference / Temperature for...
# Monod
#     halfsat                  [in] monod half-saturation constant
#     resource                 [in] label reference /
# Steele
#     i_0                      [in] label reference / Light forcing
#     kc                       [in] light attenuation coef for pigmen...
#     pigment_biomass          [in] label reference /
#     i_opt                    [in] Optimal irradiance of consumer
#     mld                      [in] label reference / Mixed Layer Dep...
#     kw                       [in] light attenuation coef for water
# Upwelling
#     n_0                      [in] label reference / nutrient concen...
#     n                        [in] label reference / nutrient mixed ...
# Mixing
#     vars_sink                [in] ('sinking_vars',) label reference...
# Growth
#     mu_max                   [in] maximum growth rate
#     resource                 [in] label reference /
#     consumer                 [in] label reference /
# GGE
#     epsilon                  [in] net production efficiency
#     egested_detritus         [in] label reference /
#     beta                     [in] absorption efficiency
#     assimilated_consumer     [in] label reference /
#     excreted_nutrient        [in] label reference /
# Solver

# %%
# Set common location of global slab forcing
forcing_location = {'lat':47,'lon':-20,'rbb':2}

odeint_setup = phydra.setup('odeint', NPZD,
            time=np.arange(0,365*5),
            input_vars={
                    # State variables
                    'Nutrient':{'var_label':'N','var_init':1.},
                    'Phytoplankton':{'var_label':'P','var_init':1.},
                    'Zooplankton':{'var_label':'Z','var_init':1.},
                    'Detritus':{'var_label':'D','var_init':1.},
                
                    # Mixing:
                    'K':{'mld':'MLD', 'mld_deriv':'MLDderiv', 
                              'kappa':0.13},
                    'Upwelling':{'n':'N', 'n_0':'N0'},
                    'Mixing':{'vars_sink':['P','Z','D']},
                    'Sinking':{'var':'D', 'mld':'MLD', 'rate':6.43},

                    # Growth
                    'Growth':{'consumer':'P', 'resource':'N', 'mu_max':1.,},
                    'Monod':{'resource':'N', 'halfsat':.85},
                    'Steele':{'pigment_biomass':'P','i_0':'I0', 'mld':'MLD',
                          'kw':0.04, 'kc':0.03, 'i_opt':10},
                    'Eppley':{'temp':'Tmld', 'eppley_exp':0.063},

                    # Grazing
                    'Grazing':{'resources':['P','D'], 'consumer':'Z',
                           'feed_prefs':[.67,.33],'Imax':1., 'kZ':.6},
                    'GGE':{'assimilated_consumer':'Z', 'egested_detritus':'D', 'excreted_nutrient':'N', 
                           'epsilon':0.75, 'beta':0.69},

                    # Mortality & sinking
                    'PhytoLinMortality':{'source':'P', 'sink':'D', 'rate':0.1},
                    'PhytoQuadMortality':{'source':'P', 'sink':'D', 'rate':0.01},
                    'ZooLinMortality':{'source':'Z', 'sink':'D', 'rate':0.1},
                    'HigherOrderPred':{'var':'Z', 'rate':0.34},
                    'DetRemineralisation':{'source':'D', 'sink':'N', 'rate':0.1},

                    # Forcings
                    'N0':{**forcing_location, 'forcing_label':'N0', 'dataset':'n0x',
                          'smooth':5, 'k':2, 'deriv':0},
                    'Tmld':{**forcing_location, 'forcing_label':'Tmld', 'dataset':'tmld',
                          'smooth':5, 'k':2, 'deriv':0},
                    'I0':{**forcing_location, 'forcing_label':'I0', 'dataset':'par',
                          'smooth':10, 'k':2, 'deriv':0},
                    'MLD':{**forcing_location, 'forcing_label':'MLD', 'dataset':'mld',
                          'smooth':400, 'k':2, 'deriv':0},
                    'MLDderiv':{**forcing_location, 'forcing_label':'MLDderiv', 'dataset':'mld',
                          'smooth':400, 'k':2, 'deriv':1}
            },
            output_vars="ALL"
            )

# %%
print(odeint_setup)
# Out:
# <xarray.Dataset>
# Dimensions:                      (clock: 2, input_time: 1825, resources: 2, sinking_vars: 3)
# Coordinates:
#   * clock                        (clock) int64 0 1
# Dimensions without coordinates: input_time, resources, sinking_vars
# Data variables:
#     Nutrient__var_label          <U1 'N'
#     Nutrient__var_init           float64 1.0
#     Phytoplankton__var_label     <U1 'P'
#     Phytoplankton__var_init      float64 1.0
#     Zooplankton__var_label       <U1 'Z'
#     Zooplankton__var_init        float64 1.0
#     Detritus__var_label          <U1 'D'
#     Detritus__var_init           float64 1.0
#     K__mld                       <U3 'MLD'
#     K__mld_deriv                 <U8 'MLDderiv'
#     K__kappa                     float64 0.13
#     Upwelling__n                 <U1 'N'
#     Upwelling__n_0               <U2 'N0'
#     Mixing__vars_sink            (sinking_vars) <U1 'P' 'Z' 'D'
#     Sinking__var                 <U1 'D'
#     Sinking__mld                 <U3 'MLD'
#     Sinking__rate                float64 6.43
#     Growth__consumer             <U1 'P'
#     Growth__resource             <U1 'N'
#     Growth__mu_max               float64 1.0
#     Monod__resource              <U1 'N'
#     Monod__halfsat               float64 0.85
#     Steele__pigment_biomass      <U1 'P'
#     Steele__i_0                  <U2 'I0'
#     Steele__mld                  <U3 'MLD'
#     Steele__kw                   float64 0.04
#     Steele__kc                   float64 0.03
#     Steele__i_opt                int64 10
#     Eppley__temp                 <U4 'Tmld'
#     Eppley__eppley_exp           float64 0.063
#     Grazing__resources           (resources) <U1 'P' 'D'
#     Grazing__consumer            <U1 'Z'
#     Grazing__feed_prefs          (resources) float64 0.67 0.33
#     Grazing__Imax                float64 1.0
#     Grazing__kZ                  float64 0.6
#     GGE__assimilated_consumer    <U1 'Z'
#     GGE__egested_detritus        <U1 'D'
#     GGE__excreted_nutrient       <U1 'N'
#     GGE__epsilon                 float64 0.75
#     GGE__beta                    float64 0.69
#     PhytoLinMortality__source    <U1 'P'
#     PhytoLinMortality__sink      <U1 'D'
#     PhytoLinMortality__rate      float64 0.1
#     PhytoQuadMortality__source   <U1 'P'
#     PhytoQuadMortality__sink     <U1 'D'
#     PhytoQuadMortality__rate     float64 0.01
#     ZooLinMortality__source      <U1 'Z'
#     ZooLinMortality__sink        <U1 'D'
#     ZooLinMortality__rate        float64 0.1
#     HigherOrderPred__var         <U1 'Z'
#     HigherOrderPred__rate        float64 0.34
#     DetRemineralisation__source  <U1 'D'
#     DetRemineralisation__sink    <U1 'N'
#     DetRemineralisation__rate    float64 0.1
#     N0__lat                      int64 47
#     N0__lon                      int64 -20
#     N0__rbb                      int64 2
#     N0__forcing_label            <U2 'N0'
#     N0__dataset                  <U3 'n0x'
#     N0__smooth                   int64 5
#     N0__k                        int64 2
#     N0__deriv                    int64 0
#     Tmld__lat                    int64 47
#     Tmld__lon                    int64 -20
#     Tmld__rbb                    int64 2
#     Tmld__forcing_label          <U4 'Tmld'
#     Tmld__dataset                <U4 'tmld'
#     Tmld__smooth                 int64 5
#     Tmld__k                      int64 2
#     Tmld__deriv                  int64 0
#     I0__lat                      int64 47
#     I0__lon                      int64 -20
#     I0__rbb                      int64 2
#     I0__forcing_label            <U2 'I0'
#     I0__dataset                  <U3 'par'
#     I0__smooth                   int64 10
#     I0__k                        int64 2
#     I0__deriv                    int64 0
#     MLD__lat                     int64 47
#     MLD__lon                     int64 -20
#     MLD__rbb                     int64 2
#     MLD__forcing_label           <U3 'MLD'
#     MLD__dataset                 <U3 'mld'
#     MLD__smooth                  int64 400
#     MLD__k                       int64 2
#     MLD__deriv                   int64 0
#     MLDderiv__lat                int64 47
#     MLDderiv__lon                int64 -20
#     MLDderiv__rbb                int64 2
#     MLDderiv__forcing_label      <U8 'MLDderiv'
#     MLDderiv__dataset            <U3 'mld'
#     MLDderiv__smooth             int64 400
#     MLDderiv__k                  int64 2
#     MLDderiv__deriv              int64 1
#     Core__solver_type            <U6 'odeint'
#     Time__time                   (input_time) int64 0 1 2 3 ... 1822 1823 1824
# Attributes:
#     __xsimlab_output_vars__:  Nutrient__var_value,Phytoplankton__var_value,Zo...

# %%
with NPZD:
    odeint_out = odeint_setup.xsimlab.run()
# Out:
# initializing model backend
# Initializing Model Time
# Initializing component Nutrient
# Initializing component Phytoplankton
# Initializing component Zooplankton
# Initializing component Detritus
# Initializing component MLD
# Initializing component Tmld
# Initializing component N0
# Initializing component MLDderiv
# Initializing component I0
# Initializing component K
# Initializing component Sinking
# Initializing component PhytoQuadMortality
# Initializing component DetRemineralisation
# Initializing component HigherOrderPred
# Initializing component Grazing
# Initializing component ZooLinMortality
# Initializing component PhytoLinMortality
# Initializing component Eppley
# Initializing component Monod
# Initializing component Steele
# Initializing component Upwelling
# Initializing component Mixing
# Initializing component Growth
# Initializing component GGE
# assembling model
# SOLVER : <phydra.backend.solvers.ODEINTSolver object at 0x11d572c40>
# Model is assembled:
# Model contains:
# Variables:['time', 'N', 'P', 'Z', 'D']
# Parameters:['MLD_dataset', 'MLD_lat', 'MLD_lon', 'MLD_rbb', 'MLD_smooth', 'MLD_k', 'MLD_deriv', 'Tmld_dataset', 'Tmld_lat', 'Tmld_lon', 'Tmld_rbb', 'Tmld_smooth', 'Tmld_k', 'Tmld_deriv', 'N0_dataset', 'N0_lat', 'N0_lon', 'N0_rbb', 'N0_smooth', 'N0_k', 'N0_deriv', 'MLDderiv_dataset', 'MLDderiv_lat', 'MLDderiv_lon', 'MLDderiv_rbb', 'MLDderiv_smooth', 'MLDderiv_k', 'MLDderiv_deriv', 'I0_dataset', 'I0_lat', 'I0_lon', 'I0_rbb', 'I0_smooth', 'I0_k', 'I0_deriv', 'K_kappa', 'Sinking_rate', 'PhytoQuadMortality_rate', 'DetRemineralisation_rate', 'HigherOrderPred_rate', 'Grazing_feed_prefs', 'Grazing_Imax', 'Grazing_kZ', 'ZooLinMortality_rate', 'PhytoLinMortality_rate', 'Eppley_eppley_exp', 'Monod_halfsat', 'Steele_i_opt', 'Steele_kw', 'Steele_kc', 'Growth_mu_max', 'GGE_beta', 'GGE_epsilon']
# Forcings:['MLD', 'Tmld', 'N0', 'MLDderiv', 'I0']
# Fluxes:['Time_time_flux', 'K_mixing', 'Sinking_sinking', 'PhytoQuadMortality_decay', 'DetRemineralisation_decay', 'HigherOrderPred_decay', 'Grazing_grazing', 'ZooLinMortality_decay', 'PhytoLinMortality_decay', 'Eppley_eppley_growth', 'Monod_monod_lim', 'Steele_steele_light_lim', 'Upwelling_mixing', 'Mixing_mixing', 'Growth_growth', 'GGE_assimilation', 'GGE_egestion', 'GGE_excretion']
# Full Model Dimensions:[('time', None), ('N', None), ('P', None), ('Z', None), ('D', None), ('Time_time_flux', None), ('K_mixing', None), ('Sinking_sinking', None), ('PhytoQuadMortality_decay', None), ('DetRemineralisation_decay', None), ('HigherOrderPred_decay', None), ('Grazing_grazing', 2), ('ZooLinMortality_decay', None), ('PhytoLinMortality_decay', None), ('Eppley_eppley_growth', None), ('Monod_monod_lim', None), ('Steele_steele_light_lim', None), ('Upwelling_mixing', None), ('Mixing_mixing', 3), ('Growth_growth', None), ('GGE_assimilation', None), ('GGE_egestion', None), ('GGE_excretion', None)]
#
# finalizing: cleanup
# Model was solved in 3.21941 seconds

# %%
print(odeint_out)
# Out:
# <xarray.Dataset>
# Dimensions:                           (clock: 2, input_time: 1825, resources: 2, sinking_vars: 3, sinking_vars_full: 3, time: 1825)
# Coordinates:
#   * clock                             (clock) int64 0 1
# Dimensions without coordinates: input_time, resources, sinking_vars, sinking_vars_full, time
# Data variables:
#     Core__solver_type                 <U6 'odeint'
#     DetRemineralisation__decay_value  (time) float64 0.1 0.09917 ... 0.04731
#     DetRemineralisation__rate         float64 0.1
#     DetRemineralisation__sink         <U1 'N'
#     DetRemineralisation__source       <U1 'D'
#     Detritus__var_init                float64 1.0
#     Detritus__var_label               <U1 'D'
#     Detritus__var_value               (time) float64 1.0 0.9608 ... 0.4761
#     Eppley__eppley_exp                float64 0.063
#     Eppley__eppley_growth_label       <U20 'Eppley_eppley_growth'
#     Eppley__eppley_growth_value       (time) float64 2.32 2.318 ... 2.333 2.328
#     Eppley__temp                      <U4 'Tmld'
#     GGE__assimilated_consumer         <U1 'Z'
#     GGE__assimilation_value           (time) float64 0.3805 0.3384 ... 1.51e-07
#     GGE__beta                         float64 0.69
#     GGE__egested_detritus             <U1 'D'
#     GGE__egestion_value               (time) float64 0.2279 0.2027 ... 9.044e-08
#     GGE__epsilon                      float64 0.75
#     GGE__excreted_nutrient            <U1 'N'
#     GGE__excretion_value              (time) float64 0.1268 0.1128 ... 5.032e-08
#     Grazing__Imax                     float64 1.0
#     Grazing__consumer                 <U1 'Z'
#     Grazing__feed_prefs               (resources) float64 0.67 0.33
#     Grazing__grazing_label            <U15 'Grazing_grazing'
#     Grazing__grazing_value            (resources, time) float64 0.4926 ... 5....
#     Grazing__kZ                       float64 0.6
#     Grazing__resources                (resources) <U1 'P' 'D'
#     Growth__consumer                  <U1 'P'
#     Growth__growth_value              (time) float64 0.1605 0.1447 ... 0.09336
#     Growth__mu_max                    float64 1.0
#     Growth__resource                  <U1 'N'
#     HigherOrderPred__decay_value      (time) float64 0.34 0.3137 ... 9.77e-14
#     HigherOrderPred__rate             float64 0.34
#     HigherOrderPred__var              <U1 'Z'
#     I0__dataset                       <U3 'par'
#     I0__deriv                         int64 0
#     I0__forcing_label                 <U2 'I0'
#     I0__forcing_value                 (time) float64 7.521 7.594 ... 7.388 7.452
#     I0__k                             int64 2
#     I0__lat                           int64 47
#     I0__lon                           int64 -20
#     I0__rbb                           int64 2
#     I0__smooth                        int64 10
#     K__kappa                          float64 0.13
#     K__mixing_label                   <U8 'K_mixing'
#     K__mixing_value                   (time) float64 0.01214 0.01196 ... 0.01224
#     K__mld                            <U3 'MLD'
#     K__mld_deriv                      <U8 'MLDderiv'
#     MLD__dataset                      <U3 'mld'
#     MLD__deriv                        int64 0
#     MLD__forcing_label                <U3 'MLD'
#     MLD__forcing_value                (time) float64 160.4 162.2 ... 156.8 158.6
#     MLD__k                            int64 2
#     MLD__lat                          int64 47
#     MLD__lon                          int64 -20
#     MLD__rbb                          int64 2
#     MLD__smooth                       int64 400
#     MLDderiv__dataset                 <U3 'mld'
#     MLDderiv__deriv                   int64 1
#     MLDderiv__forcing_label           <U8 'MLDderiv'
#     MLDderiv__forcing_value           (time) float64 1.818 1.78 ... 1.795 1.806
#     MLDderiv__k                       int64 2
#     MLDderiv__lat                     int64 47
#     MLDderiv__lon                     int64 -20
#     MLDderiv__rbb                     int64 2
#     MLDderiv__smooth                  int64 400
#     Mixing__mixing_value              (sinking_vars_full, time) float64 0.012...
#     Mixing__vars_sink                 (sinking_vars) <U1 'P' 'Z' 'D'
#     Monod__halfsat                    float64 0.85
#     Monod__monod_lim_label            <U15 'Monod_monod_lim'
#     Monod__monod_lim_value            (time) float64 0.5405 0.5544 ... 0.3769
#     Monod__resource                   <U1 'N'
#     N0__dataset                       <U3 'n0x'
#     N0__deriv                         int64 0
#     N0__forcing_label                 <U2 'N0'
#     N0__forcing_value                 (time) float64 5.09 5.133 ... 5.003 5.047
#     N0__k                             int64 2
#     N0__lat                           int64 47
#     N0__lon                           int64 -20
#     N0__rbb                           int64 2
#     N0__smooth                        int64 5
#     Nutrient__var_init                float64 1.0
#     Nutrient__var_label               <U1 'N'
#     Nutrient__var_value               (time) float64 1.0 1.116 ... 0.5095 0.5186
#     PhytoLinMortality__decay_value    (time) float64 0.1 0.08159 ... 0.07294
#     PhytoLinMortality__rate           float64 0.1
#     PhytoLinMortality__sink           <U1 'D'
#     PhytoLinMortality__source         <U1 'P'
#     PhytoQuadMortality__decay_value   (time) float64 0.01 0.006748 ... 0.005321
#     PhytoQuadMortality__rate          float64 0.01
#     PhytoQuadMortality__sink          <U1 'D'
#     PhytoQuadMortality__source        <U1 'P'
#     Phytoplankton__var_init           float64 1.0
#     Phytoplankton__var_label          <U1 'P'
#     Phytoplankton__var_value          (time) float64 1.0 0.6685 ... 0.7325
#     Sinking__mld                      <U3 'MLD'
#     Sinking__rate                     float64 6.43
#     Sinking__sinking_value            (time) float64 0.04008 0.03953 ... 0.01929
#     Sinking__var                      <U1 'D'
#     Steele__i_0                       <U2 'I0'
#     Steele__i_opt                     int64 10
#     Steele__kc                        float64 0.03
#     Steele__kw                        float64 0.04
#     Steele__mld                       <U3 'MLD'
#     Steele__pigment_biomass           <U1 'P'
#     Steele__steele_light_lim_label    <U23 'Steele_steele_light_lim'
#     Steele__steele_light_lim_value    (time) float64 0.128 0.1388 ... 0.1459
#     Time__time                        (input_time) int64 0 1 2 ... 1823 1824
#     Tmld__dataset                     <U4 'tmld'
#     Tmld__deriv                       int64 0
#     Tmld__forcing_label               <U4 'Tmld'
#     Tmld__forcing_value               (time) float64 13.36 13.33 ... 13.43 13.39
#     Tmld__k                           int64 2
#     Tmld__lat                         int64 47
#     Tmld__lon                         int64 -20
#     Tmld__rbb                         int64 2
#     Tmld__smooth                      int64 5
#     Upwelling__mixing_value           (time) float64 0.04966 0.04847 ... 0.05522
#     Upwelling__n                      <U1 'N'
#     Upwelling__n_0                    <U2 'N0'
#     ZooLinMortality__decay_value      (time) float64 0.1 0.09602 ... 5.357e-08
#     ZooLinMortality__rate             float64 0.1
#     ZooLinMortality__sink             <U1 'D'
#     ZooLinMortality__source           <U1 'Z'
#     Zooplankton__var_init             float64 1.0
#     Zooplankton__var_label            <U1 'Z'
#     Zooplankton__var_value            (time) float64 1.0 0.9172 ... 5.825e-07

# %%
time = odeint_out.Time__time

plt.plot(time, odeint_out.MLD__forcing_value, label='MLD')
plt.ylim(bottom=0)
plt.legend()
plt.show()

plt.plot(time, odeint_out.MLDderiv__forcing_value, label='MLDderiv')
plt.legend()
plt.show()

plt.plot(time, odeint_out.I0__forcing_value, label='I0')
plt.plot(time, odeint_out.N0__forcing_value, label='N0')
plt.plot(time, odeint_out.Tmld__forcing_value, label='Tmld')
plt.ylim(bottom=0)
plt.legend()

# %%
time = odeint_out.Time__time
plt.plot(time, odeint_out.Nutrient__var_value, label='N')
plt.ylim(bottom=0)
plt.legend()

# %%
time = odeint_out.Time__time
plt.plot(time, odeint_out.Nutrient__var_value, label='N')
plt.plot(time, odeint_out.Phytoplankton__var_value, label='P')
plt.plot(time, odeint_out.Zooplankton__var_value, label='Z')
plt.plot(time, odeint_out.Detritus__var_value, label='D')
plt.ylim(bottom=0)
plt.legend()

# %%
plt.plot(time, -odeint_out.PhytoLinMortality__decay_value, label='P linear mortality')
plt.plot(time, -odeint_out.PhytoQuadMortality__decay_value, label='P quad mortality')
plt.plot(time, odeint_out.Growth__growth_value, label='Phyto growth')

plt.legend()

# %%
stepwise_setup = phydra.update_setup(model=NPZD, old_setup=odeint_setup, new_solver="stepwise",
                                     new_time=np.arange(0,365*5,.5))

# %%
with NPZD:
    stepwise_out = stepwise_setup.xsimlab.run()
# Out:
# initializing model backend
# Initializing Model Time
# Initializing component Nutrient
# Initializing component Phytoplankton
# Initializing component Zooplankton
# Initializing component Detritus
# Initializing component MLD
# Initializing component Tmld
# Initializing component N0
# Initializing component MLDderiv
# Initializing component I0
# Initializing component K
# Initializing component Sinking
# Initializing component PhytoQuadMortality
# Initializing component DetRemineralisation
# Initializing component HigherOrderPred
# Initializing component Grazing
# Initializing component ZooLinMortality
# Initializing component PhytoLinMortality
# Initializing component Eppley
# Initializing component Monod
# Initializing component Steele
# Initializing component Upwelling
# Initializing component Mixing
# Initializing component Growth
# Initializing component GGE
# assembling model
# SOLVER : <phydra.backend.solvers.StepwiseSolver object at 0x16cde9af0>
# Model is assembled:
# Model contains:
# Variables:['time', 'N', 'P', 'Z', 'D']
# Parameters:['MLD_dataset', 'MLD_lat', 'MLD_lon', 'MLD_rbb', 'MLD_smooth', 'MLD_k', 'MLD_deriv', 'Tmld_dataset', 'Tmld_lat', 'Tmld_lon', 'Tmld_rbb', 'Tmld_smooth', 'Tmld_k', 'Tmld_deriv', 'N0_dataset', 'N0_lat', 'N0_lon', 'N0_rbb', 'N0_smooth', 'N0_k', 'N0_deriv', 'MLDderiv_dataset', 'MLDderiv_lat', 'MLDderiv_lon', 'MLDderiv_rbb', 'MLDderiv_smooth', 'MLDderiv_k', 'MLDderiv_deriv', 'I0_dataset', 'I0_lat', 'I0_lon', 'I0_rbb', 'I0_smooth', 'I0_k', 'I0_deriv', 'K_kappa', 'Sinking_rate', 'PhytoQuadMortality_rate', 'DetRemineralisation_rate', 'HigherOrderPred_rate', 'Grazing_feed_prefs', 'Grazing_Imax', 'Grazing_kZ', 'ZooLinMortality_rate', 'PhytoLinMortality_rate', 'Eppley_eppley_exp', 'Monod_halfsat', 'Steele_i_opt', 'Steele_kw', 'Steele_kc', 'Growth_mu_max', 'GGE_beta', 'GGE_epsilon']
# Forcings:['MLD', 'Tmld', 'N0', 'MLDderiv', 'I0']
# Fluxes:['Time_time_flux', 'K_mixing', 'Sinking_sinking', 'PhytoQuadMortality_decay', 'DetRemineralisation_decay', 'HigherOrderPred_decay', 'Grazing_grazing', 'ZooLinMortality_decay', 'PhytoLinMortality_decay', 'Eppley_eppley_growth', 'Monod_monod_lim', 'Steele_steele_light_lim', 'Upwelling_mixing', 'Mixing_mixing', 'Growth_growth', 'GGE_assimilation', 'GGE_egestion', 'GGE_excretion']
# Full Model Dimensions:[('time', None), ('N', None), ('P', None), ('Z', None), ('D', None), ('Time_time_flux', None), ('K_mixing', None), ('Sinking_sinking', None), ('PhytoQuadMortality_decay', None), ('DetRemineralisation_decay', None), ('HigherOrderPred_decay', None), ('Grazing_grazing', 2), ('ZooLinMortality_decay', None), ('PhytoLinMortality_decay', None), ('Eppley_eppley_growth', None), ('Monod_monod_lim', None), ('Steele_steele_light_lim', None), ('Upwelling_mixing', None), ('Mixing_mixing', 3), ('Growth_growth', None), ('GGE_assimilation', None), ('GGE_egestion', None), ('GGE_excretion', None)]
#
# finalizing: cleanup
# Model was solved in 6.77715 seconds

# %%
time = stepwise_out.Time__time
plt.plot(time, stepwise_out.Nutrient__var_value, label='N')
plt.plot(time, stepwise_out.Phytoplankton__var_value, label='P')
plt.plot(time, stepwise_out.Zooplankton__var_value, label='Z')
plt.plot(time, stepwise_out.Detritus__var_value, label='D')
plt.ylim(bottom=0)
plt.legend()

# %%
#plt.plot(time, stepwise_out.Input__input_value, label='N_input')
plt.plot(time, -stepwise_out.PhytoLinMortality__decay_value, label='P mortality')
plt.plot(time, -stepwise_out.PhytoQuadMortality__decay_value, label='P quad mortality')
plt.plot(time, stepwise_out.Growth__growth_value, label='N uptake')
#plt.plot(time, stepwise_out.Grazing__grazing_value, label='Grazing')
#plt.ylim(bottom=0)
plt.legend()

# %%
gekko_setup = phydra.update_setup(model=NPZD, 
                                  old_setup=odeint_setup, 
                                  new_solver="gekko", 
                                  # gekko solver works better (much faster) with smaller time steps:
                                  # new_time=np.arange(0,201,.1)
                                 )

# %%
with NPZD:
    gekko_out = gekko_setup.xsimlab.run()
# Out:
# initializing model backend
# Initializing Model Time
# XXXXXXX creating intermediate time_time_flux None
# Initializing component Nutrient
# Initializing component Phytoplankton
# Initializing component Zooplankton
# Initializing component Detritus
# Initializing component MLD
# Initializing component Tmld
# Initializing component N0
# Initializing component MLDderiv
# Initializing component I0
# Initializing component K
# XXXXXXX creating intermediate k_mixing None
# Initializing component Sinking
# XXXXXXX creating intermediate xsinking_sinking None
# Initializing component PhytoQuadMortality
# XXXXXXX creating intermediate phytoquadmortality_decay None
# Initializing component DetRemineralisation
# XXXXXXX creating intermediate detremineralisation_decay None
# Initializing component HigherOrderPred
# XXXXXXX creating intermediate higherorderpred_decay None
# Initializing component Grazing
# signaturizing
# XXXXXXX creating intermediate grazing_grazing0 None
# XXXXXXX creating intermediate grazing_grazing1 None
# Initializing component ZooLinMortality
# XXXXXXX creating intermediate zoolinmortality_decay None
# Initializing component PhytoLinMortality
# XXXXXXX creating intermediate phytolinmortality_decay None
# Initializing component Eppley
# XXXXXXX creating intermediate eppley_eppley_growth None
# Initializing component Monod
# XXXXXXX creating intermediate monod_monod_lim None
# Initializing component Steele
# XXXXXXX creating intermediate steele_steele_light_lim None
# Initializing component Upwelling
# XXXXXXX creating intermediate upwelling_mixing None
# Initializing component Mixing
# signaturizing
# XXXXXXX creating intermediate mixing_mixing0 None
# XXXXXXX creating intermediate mixing_mixing1 None
# XXXXXXX creating intermediate mixing_mixing2 None
# Initializing component Growth
# signaturizing
# XXXXXXX creating intermediate growth_growth None
# Initializing component GGE
# signaturizing
# XXXXXXX creating intermediate gge_assimilation None
# signaturizing
# XXXXXXX creating intermediate gge_egestion None
# signaturizing
# XXXXXXX creating intermediate gge_excretion None
# assembling model
# SOLVER : <phydra.backend.solvers.GEKKOSolver object at 0x16d04d490>
# Model dicts are assembled:
# Model contains:
# Variables:['time', 'N', 'P', 'Z', 'D']
# Parameters:['MLD_dataset', 'MLD_lat', 'MLD_lon', 'MLD_rbb', 'MLD_smooth', 'MLD_k', 'MLD_deriv', 'Tmld_dataset', 'Tmld_lat', 'Tmld_lon', 'Tmld_rbb', 'Tmld_smooth', 'Tmld_k', 'Tmld_deriv', 'N0_dataset', 'N0_lat', 'N0_lon', 'N0_rbb', 'N0_smooth', 'N0_k', 'N0_deriv', 'MLDderiv_dataset', 'MLDderiv_lat', 'MLDderiv_lon', 'MLDderiv_rbb', 'MLDderiv_smooth', 'MLDderiv_k', 'MLDderiv_deriv', 'I0_dataset', 'I0_lat', 'I0_lon', 'I0_rbb', 'I0_smooth', 'I0_k', 'I0_deriv', 'K_kappa', 'Sinking_rate', 'PhytoQuadMortality_rate', 'DetRemineralisation_rate', 'HigherOrderPred_rate', 'Grazing_feed_prefs', 'Grazing_Imax', 'Grazing_kZ', 'ZooLinMortality_rate', 'PhytoLinMortality_rate', 'Eppley_eppley_exp', 'Monod_halfsat', 'Steele_i_opt', 'Steele_kw', 'Steele_kc', 'Growth_mu_max', 'GGE_beta', 'GGE_epsilon']
# Forcings:['MLD', 'Tmld', 'N0', 'MLDderiv', 'I0']
# Fluxes:['Time_time_flux', 'K_mixing', 'Sinking_sinking', 'PhytoQuadMortality_decay', 'DetRemineralisation_decay', 'HigherOrderPred_decay', 'Grazing_grazing', 'ZooLinMortality_decay', 'PhytoLinMortality_decay', 'Eppley_eppley_growth', 'Monod_monod_lim', 'Steele_steele_light_lim', 'Upwelling_mixing', 'Mixing_mixing', 'Growth_growth', 'GGE_assimilation', 'GGE_egestion', 'GGE_excretion']
# Full Model Dimensions:[('time', None), ('N', None), ('P', None), ('Z', None), ('D', None), ('Time_time_flux', None), ('K_mixing', None), ('Sinking_sinking', None), ('PhytoQuadMortality_decay', None), ('DetRemineralisation_decay', None), ('HigherOrderPred_decay', None), ('Grazing_grazing', 2), ('ZooLinMortality_decay', None), ('PhytoLinMortality_decay', None), ('Eppley_eppley_growth', None), ('Monod_monod_lim', None), ('Steele_steele_light_lim', None), ('Upwelling_mixing', None), ('Mixing_mixing', 3), ('Growth_growth', None), ('GGE_assimilation', None), ('GGE_egestion', None), ('GGE_excretion', None)]
#
# Now assembling gekko model:
# Model equations:
# time_time_flux=$time
# $n=(((detremineralisation_decay+upwelling_mixing)+(-growth_growth))+gge_excretion)
# $p=(((((-phytoquadmortality_decay)+(-phytolinmortality_decay))+growth_growth)+(-grazing_grazing0))+(-mixing_mixing0))
# $z=((((-higherorderpred_decay)+(-zoolinmortality_decay))+gge_assimilation)+(-mixing_mixing1))
# $d=((((((((-xsinking_sinking)+phytoquadmortality_decay)+(-detremineralisation_decay))+zoolinmortality_decay)+phytolinmortality_decay)+gge_egestion)+(-grazing_grazing1))+(-mixing_mixing2))
# time 0 <class 'int'> 1825
# n 1.0 <class 'float'> 1825
# p 1.0 <class 'float'> 1825
# z 1.0 <class 'float'> 1825
# d 1.0 <class 'float'> 1825
# mld_lat 47.0 <class 'float'> 1825
# mld_lon -20.0 <class 'float'> 1825
# mld_rbb 2.0 <class 'float'> 1825
# mld_smooth 400.0 <class 'float'> 1825
# mld_k 2.0 <class 'float'> 1825
# mld_deriv 0.0 <class 'float'> 1825
# mld [160.42073947 162.21964143 163.98088737 ... 155.01841292 156.80788547
#  158.60866099] <class 'numpy.ndarray'> 1825
# tmld_lat 47.0 <class 'float'> 1825
# tmld_lon -20.0 <class 'float'> 1825
# tmld_rbb 2.0 <class 'float'> 1825
# tmld_smooth 5.0 <class 'float'> 1825
# tmld_k 2.0 <class 'float'> 1825
# tmld_deriv 0.0 <class 'float'> 1825
# tmld [13.36012569 13.32566318 13.29171491 ... 13.46407247 13.42947068
#  13.39482175] <class 'numpy.ndarray'> 1825
# n0_lat 47.0 <class 'float'> 1825
# n0_lon -20.0 <class 'float'> 1825
# n0_rbb 2.0 <class 'float'> 1825
# n0_smooth 5.0 <class 'float'> 1825
# n0_k 2.0 <class 'float'> 1825
# n0_deriv 0.0 <class 'float'> 1825
# n0 [5.08990988 5.13285976 5.1751093  ... 4.95943891 5.00305608 5.04654641] <class 'numpy.ndarray'> 1825
# mldderiv_lat 47.0 <class 'float'> 1825
# mldderiv_lon -20.0 <class 'float'> 1825
# mldderiv_rbb 2.0 <class 'float'> 1825
# mldderiv_smooth 400.0 <class 'float'> 1825
# mldderiv_k 2.0 <class 'float'> 1825
# mldderiv_deriv 1.0 <class 'float'> 1825
# mldderiv [1.81772996 1.78007395 1.74241794 ... 1.78382107 1.79512403 1.806427  ] <class 'numpy.ndarray'> 1825
# i0_lat 47.0 <class 'float'> 1825
# i0_lon -20.0 <class 'float'> 1825
# i0_rbb 2.0 <class 'float'> 1825
# i0_smooth 10.0 <class 'float'> 1825
# i0_k 2.0 <class 'float'> 1825
# i0_deriv 0.0 <class 'float'> 1825
# i0 [7.52064993 7.59417803 7.67171617 ... 7.33034137 7.38838628 7.45182247] <class 'numpy.ndarray'> 1825
# k_kappa 0.13 <class 'float'> 1825
# p37 [1.81772996 1.78007395 1.74241794 ... 1.78382107 1.79512403 1.806427  ] <class 'numpy.ndarray'> 1825
# xsinking_rate 6.43 <class 'float'> 1825
# phytoquadmortality_rate 0.01 <class 'float'> 1825
# detremineralisation_rate 0.1 <class 'float'> 1825
# higherorderpred_rate 0.34 <class 'float'> 1825
# grazing_feed_prefs0 0.67 <class 'float'> 1825
# grazing_feed_prefs1 0.33 <class 'float'> 1825
# grazing_imax 1.0 <class 'float'> 1825
# grazing_kz 0.6 <class 'float'> 1825
# zoolinmortality_rate 0.1 <class 'float'> 1825
# phytolinmortality_rate 0.1 <class 'float'> 1825
# eppley_eppley_exp 0.063 <class 'float'> 1825
# monod_halfsat 0.85 <class 'float'> 1825
# steele_i_opt 10.0 <class 'float'> 1825
# steele_kw 0.04 <class 'float'> 1825
# steele_kc 0.03 <class 'float'> 1825
# growth_mu_max 1.0 <class 'float'> 1825
# gge_beta 0.69 <class 'float'> 1825
# gge_epsilon 0.75 <class 'float'> 1825
# finalizing: cleanup
# Model was solved in 16.30833 seconds

# %%
time = gekko_out.Time__time
plt.plot(time, gekko_out.Nutrient__var_value, label='N')
plt.plot(time, gekko_out.Phytoplankton__var_value, label='P')
plt.plot(time, gekko_out.Zooplankton__var_value, label='Z')
plt.plot(time, gekko_out.Detritus__var_value, label='D')
plt.ylim(bottom=0)
plt.legend()

# %%
plt.plot(time, gekko_out.PhytoLinMortality__decay_value, label='P mortality')
plt.plot(time, gekko_out.PhytoQuadMortality__decay_value, label='P quad mortality')
plt.plot(time, gekko_out.Growth__growth_value, label='N uptake')
#plt.plot(time, gekko_out.Grazing__grazing_value, label='Grazing')
plt.ylim(bottom=0)
plt.legend()
